# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebadi-Fereshteh/Deep-Learning/blob/main/47_HousesPrice_Regression/47_HousesPrices_Regression_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! cd ~
! git clone https://github.com/emanhamed/Houses-dataset
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165
# Receiving objects: 100% (2166/2166), 176.26 MiB | 41.96 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !python HousesPrice_ImageRegression/cnn_regression.py --dataset HousesPrice_ImageRegression/HousesDataset
# [INFO] loading house attributes...
# [INFO] loading house images...
# [INFO] training model...
# Out:
# [INFO] loading house attributes...
# [INFO] loading house images...
# 2022-04-16 21:17:05.655659: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [INFO] training model...
# Epoch 1/200
# 34/34 [==============================] - 2s 33ms/step - loss: 1994.2404 - val_loss: 2931.3293
# Epoch 2/200
# 34/34 [==============================] - 1s 27ms/step - loss: 1555.5035 - val_loss: 412.8459
# Epoch 3/200
# 34/34 [==============================] - 1s 28ms/step - loss: 1335.2247 - val_loss: 453.8273
# Epoch 4/200
# 34/34 [==============================] - 1s 28ms/step - loss: 978.3635 - val_loss: 427.2445
# Epoch 5/200
# 34/34 [==============================] - 1s 27ms/step - loss: 844.1609 - val_loss: 388.3763
# ...
